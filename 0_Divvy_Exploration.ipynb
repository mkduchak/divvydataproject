# %%
import pandas as pd
import numpy as np

# %%
rides = pd.read_csv('/home/michael/Documents/Projects/divvy/data/Divvy Trips/Divvy_Trips_2017_Q4.csv')

# %%
rides.head()
# Out:
#     trip_id        start_time          end_time  bikeid  tripduration  \
# 0  17536701  12/31/2017 23:58     1/1/2018 0:03    3304           284
# 1  17536700  12/31/2017 23:54     1/1/2018 0:18    5975          1402
# 2  17536699  12/31/2017 23:54     1/1/2018 0:18    4906          1441
# 3  17536698  12/31/2017 23:48  12/31/2017 23:53    5667           315
# 4  17536697  12/31/2017 23:42  12/31/2017 23:47    5353           272
#
#    from_station_id                    from_station_name  to_station_id  \
# 0              159            Claremont Ave & Hirsch St             69
# 1              145  Mies van der Rohe Way & Chestnut St            145
# 2              145  Mies van der Rohe Way & Chestnut St            145
# 3              340            Clark St & Wrightwood Ave            143
# 4              240         Sheridan Rd & Irving Park Rd            245
#
#                        to_station_name    usertype gender  birthyear
# ...

# %%
rides.shape
# Out:
# (669239, 12)

# %%
rides.dtypes
# Out:
# trip_id                int64
# start_time            object
# end_time              object
# bikeid                 int64
# tripduration           int64
# from_station_id        int64
# from_station_name     object
# to_station_id          int64
# to_station_name       object
# usertype              object
# gender                object
# birthyear            float64
# dtype: object

# %%
stations = pd.read_csv('/home/michael/Documents/Projects/divvy/Divvy_Trips_2017_Q3Q4/Divvy_Stations_2017_Q3Q4.csv')

# %%
stations.head()
# Out:
#    id                    name     city   latitude  longitude  dpcapacity  \
# 0   2     Buckingham Fountain  Chicago  41.876393 -87.620328          27
# 1   3          Shedd Aquarium  Chicago  41.867226 -87.615355          55
# 2   4          Burnham Harbor  Chicago  41.856268 -87.613348          23
# 3   5  State St & Harrison St  Chicago  41.874053 -87.627716          23
# 4   6          Dusable Harbor  Chicago  41.885041 -87.612794          39
#
#        online_date  Unnamed: 7
# 0  6/10/2013 10:43         NaN
# 1  6/10/2013 10:44         NaN
# 2  6/10/2013 10:46         NaN
# 3  6/10/2013 10:46         NaN
# 4  6/10/2013 11:18         NaN

# %%
stations.shape
# Out:
# (585, 8)

# %%
weather = pd.read_csv('/home/michael/Downloads/1243492.csv')
weather.head()
# Out:
# /home/michael/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (10,11,12,13,14,15,16,17,20,22,23,25,26,27,28,29,33,34,39,40,44,45,59,63,64,67,68,69,72,73,74,84,85,86,87) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#       STATION                  STATION_NAME  ELEVATION  LATITUDE  LONGITUDE  \
# 0  WBAN:14819  CHICAGO MIDWAY AIRPORT IL US      186.5  41.78611  -87.75222
# 1  WBAN:14819  CHICAGO MIDWAY AIRPORT IL US      186.5  41.78611  -87.75222
# 2  WBAN:14819  CHICAGO MIDWAY AIRPORT IL US      186.5  41.78611  -87.75222
# 3  WBAN:14819  CHICAGO MIDWAY AIRPORT IL US      186.5  41.78611  -87.75222
# 4  WBAN:14819  CHICAGO MIDWAY AIRPORT IL US      186.5  41.78611  -87.75222
#
#                DATE REPORTTPYE   HOURLYSKYCONDITIONS HOURLYVISIBILITY  \
# 0  2013-01-01 00:51      FM-15             OVC:08 85            10.00
# ...

# %%
weather.columns
# Out:
# Index(['STATION', 'STATION_NAME', 'ELEVATION', 'LATITUDE', 'LONGITUDE', 'DATE',
#        'REPORTTPYE', 'HOURLYSKYCONDITIONS', 'HOURLYVISIBILITY',
#        'HOURLYPRSENTWEATHERTYPE', 'HOURLYDRYBULBTEMPF', 'HOURLYDRYBULBTEMPC',
#        'HOURLYWETBULBTEMPF', 'HOURLYWETBULBTEMPC', 'HOURLYDewPointTempF',
#        'HOURLYDewPointTempC', 'HOURLYRelativeHumidity', 'HOURLYWindSpeed',
#        'HOURLYWindDirection', 'HOURLYWindGustSpeed', 'HOURLYStationPressure',
#        'HOURLYPressureTendency', 'HOURLYPressureChange',
#        'HOURLYSeaLevelPressure', 'HOURLYPrecip', 'HOURLYAltimeterSetting',
#        'DAILYMaximumDryBulbTemp', 'DAILYMinimumDryBulbTemp',
#        'DAILYAverageDryBulbTemp', 'DAILYDeptFromNormalAverageTemp',
#        'DAILYAverageRelativeHumidity', 'DAILYAverageDewPointTemp',
#        'DAILYAverageWetBulbTemp', 'DAILYHeatingDegreeDays',
#        'DAILYCoolingDegreeDays', 'DAILYSunrise', 'DAILYSunset', 'DAILYWeather',
# ...

# %%
weather.shape
# Out:
# (127269, 90)

# %%
weather.groupby('STATION_NAME')[['DATE']].count()
# Out:
#                                             DATE
# STATION_NAME
# CHICAGO MIDWAY AIRPORT IL US               62305
# CHICAGO OHARE INTERNATIONAL AIRPORT IL US  64964

# %%
permitdata = pd.read_csv('/home/michael/Downloads/Chicago_Park_District_-_Event_Permits.csv')

# %%
permitdata.head()
# Out:
#            Requestor Organization  Park Number  \
# 0     William Benson           --       8480.0
# 1     Marcin Hapunik           --       8480.0
# 2     Nolberto Lopez           --       8480.0
# 3      Ruben Codrean           --       8480.0
# 4  Svitlana Dukhovna           --       8480.0
#
#                      Park/Facility Name Reservation Start Date  \
# 0  Garfield Conservatory All Show Rooms             01/07/2012
# 1  Garfield Conservatory All Show Rooms             01/07/2012
# 2  Garfield Conservatory All Show Rooms             01/07/2012
# 3  Garfield Conservatory All Show Rooms             01/08/2012
# 4   Lincoln Conservatory All Show Rooms             01/14/2012
#
#   Reservation End Date                                   Event Type  \
# 0           01/07/2012  Permit - Media:  Non-Commercial Photography
# 1           01/07/2012  Permit - Media:  Non-Commercial Photography
# 2           01/07/2012  Permit - Media:  Non-Commercial Photography
# ...

# %%
permitdata.groupby('Event Type')[['Permit Status']].count()
# Out:
#                                                     Permit Status
# Event Type
# Administrative Reservation - Internal Hold PARKS            13757
# Administrative Reservation - Internal Hold REVENUE           2034
# Administrative Reservation - Park Legacy Items               3645
# Permit - Athletic Event Level 1                              1229
# Permit - Athletic Event Level 2                               471
# Permit - Athletic Event Level 3                              1800
# Permit - Athletic Event Level 4                              1026
# Permit - Athletic Event Level 5                               825
# Permit - Athletic Training                                  28064
# Permit - Commemorative Event Level 1                          364
# Permit - Commemorative Event Level 2                          228
# Permit - Commemorative Event Level 3/TiffanyGarden             17
# Permit - Commemorative Event Level 4/TiffanyGarden             13
# ...

# %%
permitdata[permitdata['Event Type'] ==  'Permit - Festival/Performance/12,001+ Event'].tail()
# Out:
#                              Requestor Organization  Park Number  \
# 69592                    Jaclyn Little           --         24.0
# 69598  James Special Events Management           --         19.0
# 69599                    Jaclyn Little           --         24.0
# 69614                    Jaclyn Little           --         24.0
# 69635                    Jaclyn Little           --         24.0
#
#                             Park/Facility Name Reservation Start Date  \
# 69592                      Grant Tennis Courts             07/18/2018
# 69598            Jackson Soccer-3 fields E-W-N             07/01/2018
# 69599  Grant Tiffany Garden and Adjacent Lawns             08/01/2018
# 69614            Grant Lower Hutchinson Entire             08/09/2018
# 69635                  Grant North Rose Garden             07/21/2018
#
#       Reservation End Date                                   Event Type  \
# 69592           07/18/2018  Permit - Festival/Performance/12,001+ Event
# ...
